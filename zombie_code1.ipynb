# %%
import pandas as pd
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot

# %%
df = pd.read_csv('Complete List of Zombie Movies.csv')

# %%
df.head(3)
# Out:
#    Position      Const     Created    Modified  Description  \
# 0         1  tt2272350  2014-02-18  2014-02-18          NaN
# 1         2  tt0876294  2014-02-18  2014-02-18          NaN
# 2         3  tt0103959  2014-02-18  2014-02-18          NaN
#
#                 Title                                    URL Title Type  \
# 0         The Battery  https://www.imdb.com/title/tt2272350/      movie
# 1  The Zombie Diaries  https://www.imdb.com/title/tt0876294/      movie
# 2       Chrome Hearts  https://www.imdb.com/title/tt0103959/      movie
#
#    IMDb Rating  Runtime (mins)  Year                    Genres  Num Votes  \
# 0          6.3           101.0  2012  Adventure, Drama, Horror       9593
# 1          4.0            85.0  2006            Horror, Sci-Fi       4783
# 2          4.1            86.0  1989            Comedy, Horror       2030
#
#   Release Date                         Directors
# 0   2012-10-13                    Jeremy Gardner
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Position        272 non-null    int64
#  1   Const           272 non-null    object
#  2   Created         272 non-null    object
#  3   Modified        272 non-null    object
#  4   Description     0 non-null      float64
#  5   Title           272 non-null    object
#  6   URL             272 non-null    object
#  7   Title Type      272 non-null    object
#  8   IMDb Rating     272 non-null    float64
#  9   Runtime (mins)  270 non-null    float64
#  10  Year            272 non-null    int64
#  11  Genres          272 non-null    object
#  12  Num Votes       272 non-null    int64
#  13  Release Date    271 non-null    object
#  14  Directors       265 non-null    object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 32.0+ KB

# %%
df.drop(['URL'], axis = 1, inplace = True)

# %%
df.drop(['Created','Modified'], axis = 1, inplace = True)

# %%
df.drop(['Const','Position','Description'], axis = 1, inplace = True)

# %%
df.head(2)
# Out:
#                 Title Title Type  IMDb Rating  Runtime (mins)  Year  \
# 0         The Battery      movie          6.3           101.0  2012
# 1  The Zombie Diaries      movie          4.0            85.0  2006
#
#                      Genres  Num Votes Release Date  \
# 0  Adventure, Drama, Horror       9593   2012-10-13
# 1            Horror, Sci-Fi       4783   2006-10-29
#
#                           Directors
# 0                    Jeremy Gardner
# 1  Michael G. Bartlett, Kevin Gates

# %%
df['Title Type'].value_counts()
# Out:
# movie           242
# video            14
# tvSeries          6
# tvMovie           5
# videoGame         2
# tvMiniSeries      1
# musicVideo        1
# short             1
# Name: Title Type, dtype: int64

# %% [markdown]
# Since I am only interested in movies, I remove all rows that have a different title type.

# %%
df_movies = df[df['Title Type'] == 'movie']

# %%
df_movies.head()
# Out:
#                    Title Title Type  IMDb Rating  Runtime (mins)  Year  \
# 0            The Battery      movie          6.3           101.0  2012
# 1     The Zombie Diaries      movie          4.0            85.0  2006
# 2          Chrome Hearts      movie          4.1            86.0  1989
# 3  Zombies Vs. Strippers      movie          3.5            75.0  2012
# 4      Junk: Shiryô-gari      movie          5.4            83.0  2000
#
#                      Genres  Num Votes Release Date  \
# 0  Adventure, Drama, Horror       9593   2012-10-13
# 1            Horror, Sci-Fi       4783   2006-10-29
# 2            Comedy, Horror       2030   1989-10-31
# 3            Comedy, Horror        846   2012-07-09
# 4                    Horror       1164   2000-01-22
#
#                           Directors
# 0                    Jeremy Gardner
# 1  Michael G. Bartlett, Kevin Gates
# 2                       Dan Hoskins
# 3                     Alex Nicolaou
# 4                    Atsushi Muroga

# %%
df_movies.shape
# Out:
# (242, 9)

# %%
df_movies.sort_values(by=['Release Date'], inplace=True)
df_movies.head(50)
# Out:
# C:\Users\jerem\AppData\Local\Temp\ipykernel_1588\1712976260.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies.sort_values(by=['Release Date'], inplace=True)
#                                                  Title Title Type  \
# 247                       Das Cabinet des Dr. Caligari      movie
# 85                                        White Zombie      movie
# 48                                    The Walking Dead      movie
# 86                               Revolt of the Zombies      movie
# 87                                 King of the Zombies      movie
# 84                              I Walked with a Zombie      movie
# 43                              Revenge of the Zombies      movie
# 42                        Creature with the Atom Brain      movie
# ...

# %%
df_movies['Horror'] = pd.Series


#df[df['Country (region)'].str.contains('^I.*')==True]
# Out:
# C:\Users\jerem\AppData\Local\Temp\ipykernel_1588\2441386240.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies['Horror'] = pd.Series

# %%
df_movies.head()
# Out:
#                             Title Title Type  IMDb Rating  Runtime (mins)  \
# 247  Das Cabinet des Dr. Caligari      movie          8.0            76.0
# 85                   White Zombie      movie          6.2            69.0
# 48               The Walking Dead      movie          6.6            66.0
# 86          Revolt of the Zombies      movie          3.4            65.0
# 87            King of the Zombies      movie          5.2            67.0
#
#      Year                        Genres  Num Votes Release Date  \
# 247  1920     Horror, Mystery, Thriller      65778   1920-02-26
# 85   1932                        Horror      10982   1932-07-28
# 48   1936  Crime, Drama, Horror, Sci-Fi       2789   1936-03-01
# 86   1936             Adventure, Horror       1779   1936-06-04
# 87   1941     Adventure, Comedy, Horror       2340   1941-05-14
#
#            Directors                               Horror
# 247     Robert Wiene  <class 'pandas.core.series.Series'>
# ...

# %%
df_movies['Horror'] = df_movies['Genres'].str.contains('.*Horror.*')
df_movies.head()
# Out:
# C:\Users\jerem\AppData\Local\Temp\ipykernel_1588\4244360113.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies['Horror'] = df_movies['Genres'].str.contains('.*Horror.*')
#                             Title Title Type  IMDb Rating  Runtime (mins)  \
# 247  Das Cabinet des Dr. Caligari      movie          8.0            76.0
# 85                   White Zombie      movie          6.2            69.0
# 48               The Walking Dead      movie          6.6            66.0
# 86          Revolt of the Zombies      movie          3.4            65.0
# 87            King of the Zombies      movie          5.2            67.0
#
#      Year                        Genres  Num Votes Release Date  \
# ...

# %%
df_movies.head()
# Out:
#                    Title Title Type  IMDb Rating  Runtime (mins)  Year  \
# 0            The Battery      movie          6.3           101.0  2012
# 1     The Zombie Diaries      movie          4.0            85.0  2006
# 2          Chrome Hearts      movie          4.1            86.0  1989
# 3  Zombies Vs. Strippers      movie          3.5            75.0  2012
# 4      Junk: Shiryô-gari      movie          5.4            83.0  2000
#
#                      Genres  Num Votes Release Date  \
# 0  Adventure, Drama, Horror       9593   2012-10-13
# 1            Horror, Sci-Fi       4783   2006-10-29
# 2            Comedy, Horror       2030   1989-10-31
# 3            Comedy, Horror        846   2012-07-09
# 4                    Horror       1164   2000-01-22
#
#                           Directors  Horror
# 0                    Jeremy Gardner    True
# 1  Michael G. Bartlett, Kevin Gates    True
# 2                       Dan Hoskins    True
# ...

# %%
df_movies['Sci-Fi'] = df_movies['Genres'].str.contains('.*Sci-Fi.*')
df_movies['Drama'] = df_movies['Genres'].str.contains('.*Drama.*')
df_movies['Thriller'] = df_movies['Genres'].str.contains('.*Thriller.*')
df_movies['Comedy'] = df_movies['Genres'].str.contains('.*Comedy.*')

# %%
df_movies['Comedy'].value_counts()
# Out:
# False    173
# True      69
# Name: Comedy, dtype: int64

# %%
df_movies['Adventure'] = df_movies['Genres'].str.contains('.*Adventure.*')
df_movies['Action'] = df_movies['Genres'].str.contains('.*Action.*')
df_movies['Adult'] = df_movies['Genres'].str.contains('.*Adult.*')
df_movies['Mystery'] = df_movies['Genres'].str.contains('.*Mystery.*')
df_movies['Crime'] = df_movies['Genres'].str.contains('.*Crime.*')
df_movies['Romance'] = df_movies['Genres'].str.contains('.*Romance.*')

# %%
df_movies['War'] = df_movies['Genres'].str.contains('.*War.*')
df_movies['Fantasy'] = df_movies['Genres'].str.contains('.*Fantasy.*')

# %%
df_movies.head()
# Out:
#                             Title Title Type  IMDb Rating  Runtime (mins)  \
# 247  Das Cabinet des Dr. Caligari      movie          8.0            76.0
# 85                   White Zombie      movie          6.2            69.0
# 48               The Walking Dead      movie          6.6            66.0
# 86          Revolt of the Zombies      movie          3.4            65.0
# 87            King of the Zombies      movie          5.2            67.0
#
#      Year                        Genres  Num Votes Release Date  \
# 247  1920     Horror, Mystery, Thriller      65778   1920-02-26
# 85   1932                        Horror      10982   1932-07-28
# 48   1936  Crime, Drama, Horror, Sci-Fi       2789   1936-03-01
# 86   1936             Adventure, Horror       1779   1936-06-04
# 87   1941     Adventure, Comedy, Horror       2340   1941-05-14
#
#            Directors                               Horror  ...  Thriller  \
# ...

# %%
df_movies['Genres'].value_counts()
# Out:
# Horror                                     42
# Horror, Sci-Fi                             18
# Comedy, Horror                             18
# Comedy, Horror, Sci-Fi                     13
# Horror, Sci-Fi, Thriller                   12
#                                            ..
# Action, Comedy, Fantasy, Horror, Sci-Fi     1
# Comedy, Fantasy, Horror, Musical            1
# Comedy                                      1
# Drama, Horror, Romance                      1
# Animation, Action, Horror                   1
# Name: Genres, Length: 80, dtype: int64

# %%
df_movies['Animation'] = df_movies['Genres'].str.contains('.*Animation.*')
df_movies['Musical'] = df_movies['Genres'].str.contains('.*Musical.*')

# %%
df_movies['Family'] = df_movies['Genres'].str.contains('.*Family.*')
# Out:
# C:\Users\jerem\AppData\Local\Temp\ipykernel_1588\2154886502.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies['Family'] = df_movies['Genres'].str.contains('.*Family.*')

# %%
df_movies['Western'] = df_movies['Genres'].str.contains('.*Western.*')
# Out:
# C:\Users\jerem\AppData\Local\Temp\ipykernel_1588\1111711468.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies['Western'] = df_movies['Genres'].str.contains('.*Western.*')

# %%
df_movies['Family'].value_counts()
# Out:
# False    241
# True       1
# Name: Family, dtype: int64

# %%
df_movies['Title_Dead'] = df_movies['Title'].str.contains('.*Dead.*')
df_movies['Title_Zombie'] = df_movies['Title'].str.contains('.*Zombie.*')
# Out:
# C:\Users\jerem\AppData\Local\Temp\ipykernel_1588\642939854.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies['Title_Dead'] = df_movies['Title'].str.contains('.*Dead.*')
# C:\Users\jerem\AppData\Local\Temp\ipykernel_1588\642939854.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies['Title_Zombie'] = df_movies['Title'].str.contains('.*Zombie.*')

# %%
df_movies['Title_Dead'].value_counts()
# Out:
# False    197
# True      45
# Name: Title_Dead, dtype: int64

# %%
df_movies['Title_Zombie'].value_counts()
# Out:
# False    217
# True      25
# Name: Title_Zombie, dtype: int64

# %%
df_movies.columns
# Out:
# Index(['Title', 'Title Type', 'IMDb Rating', 'Runtime (mins)', 'Year',
#        'Genres', 'Num Votes', 'Release Date', 'Directors', 'Horror', 'Sci-Fi',
#        'Drama', 'Thriller', 'Comedy', 'Adventure', 'Action', 'Adult',
#        'Mystery', 'Crime', 'Romance', 'War', 'Fantasy', 'Animation', 'Musical',
#        'Western', 'Family', 'Title_Dead', 'Title_Zombie'],
#       dtype='object')

# %%
df_movies.dtypes
# Out:
# Title              object
# Title Type         object
# IMDb Rating       float64
# Runtime (mins)    float64
# Year                int64
# Genres             object
# Num Votes           int64
# Release Date       object
# Directors          object
# Horror               bool
# Sci-Fi               bool
# Drama                bool
# Thriller             bool
# Comedy               bool
# Adventure            bool
# Action               bool
# Adult                bool
# Mystery              bool
# Crime                bool
# Romance              bool
# War                  bool
# Fantasy              bool
# Animation            bool
# Musical              bool
# Western              bool
# Family               bool
# Title_Dead           bool
# Title_Zombie         bool
# dtype: object

# %%
df_cred_pd['TRANSACTION_TYPE'].value_counts().plot(kind='bar', figsize=(8, 5))
#on a graph that starts at 0, it is hard to see much difference in counts on the y axis for these types, so 
#this graph has the limits placed on the y axis which will frame the values in a clearer way.
pyplot.ylim(6500,6900)
pyplot.title('Number of Transactions by Transaction Type')
pyplot.ylabel('Number of transactions')
pyplot.xlabel('Transaction type')
pyplot.show()
